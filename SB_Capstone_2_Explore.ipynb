# %% [markdown]
# ## Galaxy Class Prediction: Exploratory Data Analysis

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load data and get overview

# %%
# Load data
df = pd.read_csv('./train_targets.csv', index_col=0).set_index('GalaxyID')

# %%
df.head()
# Out:
#           Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# GalaxyID
# 149527    0.253299  0.726236  0.020465  0.000000  0.726236  0.062870
# 469719    0.095128  0.904872  0.000000  0.562072  0.342800  0.135723
# 426608    0.827004  0.094543  0.078453  0.031483  0.063060  0.000000
# 653281    0.665337  0.303493  0.031169  0.000000  0.303493  0.102300
# 430768    0.741939  0.258061  0.000000  0.000000  0.258061  0.000000
#
#           Class3.2  Class4.1  Class4.2  Class5.1    ...      Class9.3  \
# GalaxyID                                            ...
# 149527    0.663366  0.555740  0.170496  0.020345    ...           0.0
# 469719    0.207077  0.066792  0.276008  0.000000    ...           0.0
# 426608    0.063060  0.000000  0.063060  0.000000    ...           0.0
# 653281    0.201193  0.033688  0.269805  0.000000    ...           0.0
# 430768    0.258061  0.000000  0.258061  0.000000    ...           0.0
#
#           Class10.1  Class10.2  Class10.3  Class11.1  Class11.2  Class11.3  \
# GalaxyID
# 149527     0.438479   0.117261   0.000000   0.087807    0.14616   0.175614
# 469719     0.000000   0.000000   0.066792   0.000000    0.00000   0.000000
# 426608     0.000000   0.000000   0.000000   0.000000    0.00000   0.000000
# 653281     0.000000   0.000000   0.033688   0.000000    0.00000   0.000000
# 430768     0.000000   0.000000   0.000000   0.000000    0.00000   0.000000
#
#           Class11.4  Class11.5  Class11.6
# GalaxyID
# 149527          0.0        0.0   0.146160
# 469719          0.0        0.0   0.066792
# 426608          0.0        0.0   0.000000
# 653281          0.0        0.0   0.033688
# 430768          0.0        0.0   0.000000
#
# [5 rows x 37 columns]

# %%
pd.set_option('display.max_columns', 40)
df.describe()
# Out:
#            Class1.1      Class1.2      Class1.3      Class2.1      Class2.2  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.432302      0.542595      0.025103      0.106671      0.435924
# std        0.283477      0.296403      0.037604      0.212811      0.301960
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.175566      0.281368      0.000000      0.000000      0.168213
# 50%        0.417147      0.558759      0.014837      0.000000      0.395624
# 75%        0.678720      0.811825      0.034112      0.085663      0.695328
# max        1.000000      1.000000      0.935147      1.000000      1.000000
#
#            Class3.1      Class3.2      Class4.1      Class4.2      Class5.1  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.102641      0.333283      0.215848      0.220077      0.040765
# std        0.177760      0.248000      0.285611      0.180139      0.087494
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.121989      0.000000      0.072280      0.000000
# 50%        0.000000      0.289251      0.093086      0.182998      0.000000
# 75%        0.134435      0.516143      0.330503      0.338249      0.043773
# max        1.000000      1.000000      1.000000      0.957937      0.803556
#
#            Class5.2      Class5.3      Class5.4      Class6.1      Class6.2  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.180393      0.178205      0.036562      0.231726      0.768274
# std        0.191991      0.180528      0.060126      0.227304      0.227304
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.065794      0.672202
# 50%        0.117668      0.126553      0.000000      0.148834      0.851166
# 75%        0.290767      0.285277      0.057316      0.327798      0.934206
# max        0.923000      0.870493      0.650383      1.000000      1.000000
#
#            Class7.1      Class7.2      Class7.3      Class8.1      Class8.2  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.169415      0.208308      0.054578      0.034947      0.013398
# std        0.238522      0.216523      0.110142      0.101607      0.027302
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.032360      0.000000      0.000000      0.000000
# 50%        0.035775      0.126164      0.000000      0.000000      0.000000
# 75%        0.278459      0.336164      0.048906      0.027894      0.025000
# max        1.000000      1.000000      0.849000      0.969157      0.533133
#
#            Class8.3      Class8.4      Class8.5      Class8.6      Class8.7  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.032738      0.040211      0.064671      0.041894      0.003867
# std        0.051533      0.081192      0.090440      0.107269      0.024425
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.034302      0.000000      0.000000
# 75%        0.046067      0.045223      0.086282      0.032223      0.000000
# max        0.598390      0.860000      0.785697      0.971000      0.719088
#
#            Class9.1      Class9.2      Class9.3     Class10.1     Class10.2  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.063117      0.010619      0.032935      0.091485      0.084347
# std        0.137647      0.037987      0.098239      0.144431      0.140419
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.056339      0.000000      0.000000      0.146692      0.127383
# max        0.985982      0.889493      0.901991      0.909755      0.877393
#
#           Class10.3     Class11.1     Class11.2     Class11.3     Class11.4  \
# count  41257.000000  41257.000000  41257.000000  41257.000000  41257.000000
# mean       0.040016      0.015475      0.094469      0.017811      0.007536
# std        0.099677      0.052110      0.193785      0.068920      0.037498
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.031196      0.000000      0.098998      0.000000      0.000000
# max        0.974348      0.886363      1.000000      0.975913      0.957000
#
#           Class11.5     Class11.6
# count  41257.000000  41257.000000
# mean       0.006939      0.073617
# std        0.037276      0.107187
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.129139
# max        0.938881      0.695324

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41257 entries, 149527 to 923951
# Data columns (total 37 columns):
# Class1.1     41257 non-null float64
# Class1.2     41257 non-null float64
# Class1.3     41257 non-null float64
# Class2.1     41257 non-null float64
# Class2.2     41257 non-null float64
# Class3.1     41257 non-null float64
# Class3.2     41257 non-null float64
# Class4.1     41257 non-null float64
# Class4.2     41257 non-null float64
# Class5.1     41257 non-null float64
# Class5.2     41257 non-null float64
# Class5.3     41257 non-null float64
# Class5.4     41257 non-null float64
# Class6.1     41257 non-null float64
# Class6.2     41257 non-null float64
# Class7.1     41257 non-null float64
# Class7.2     41257 non-null float64
# Class7.3     41257 non-null float64
# Class8.1     41257 non-null float64
# Class8.2     41257 non-null float64
# Class8.3     41257 non-null float64
# Class8.4     41257 non-null float64
# Class8.5     41257 non-null float64
# Class8.6     41257 non-null float64
# Class8.7     41257 non-null float64
# Class9.1     41257 non-null float64
# Class9.2     41257 non-null float64
# Class9.3     41257 non-null float64
# Class10.1    41257 non-null float64
# Class10.2    41257 non-null float64
# Class10.3    41257 non-null float64
# Class11.1    41257 non-null float64
# Class11.2    41257 non-null float64
# Class11.3    41257 non-null float64
# Class11.4    41257 non-null float64
# Class11.5    41257 non-null float64
# Class11.6    41257 non-null float64
# dtypes: float64(37)
# memory usage: 12.0 MB

# %% [markdown]
# We can see above that all class columns are uniform in data type, and that there are no missing values in the data.

# %% [markdown]
# ### Detailed Analysis

# %% [markdown]
# Before proceding, it is worth noting that the data classes listed above are based on crowd-sourced data. When the data was crowd-sourced, those labelling the data were given the tasks laid out below, with each task potentially leading to other tasks, as indicated in the "Next" column. Each class above corresponds to task and an answer below. In other words an answer of "No" on task 3 would be assigned Class 3.2.

# %% [markdown]
# <img src="./GalaxyClasses.png">

# %% [markdown]
# The above chart can, to at least some degree, be distilled into Hubble's galaxy classification system. As can be seen below, this divides galxies into ellipticals, spirals, and spiral bar classes.
# <ul>
#     <li>Ellipticals would be indicated by class 1.1 in the above, though this may not be true if it is accompanied by a high classification percentage on class 6.1.</li>
#     <li>Spirals would be indicated by classes 4.1 and 3.2 together (again, with 6.1 possibly effecting it).</li>
#     <li>Spiral bar galaxies would be indicated by classes 4.1 and 3.1 together (again, with 6.1).</li>
# </ul>
# Subclasses of each of these would be indicated in classes 7 (degrees of elliptical), or 10 and 11 (types of spiral and spiral bar galaxies).

# %% [markdown]
# <img src="./HubbleTuningFork.jpg" width=400>

# %% [markdown]
# Keeping the above in mind, let's take a look at which categories tend to be assigned more frequently than others with a high degree of agreement among data labellers.

# %%
fig, ax = plt.subplots(figsize=(16,8))
agreement_level_high = (df_plt[df_plt['percent'] >= 0.66]['classes'].value_counts()/
                   df_plt['classes'].value_counts().dropna())
agreement_level_maj = (df_plt[df_plt['percent'] > 0.5]['classes'].value_counts()/
                   df_plt['classes'].value_counts().dropna())
agreement_level_low = (df_plt[df_plt['percent'] <= 0.5]['classes'].value_counts()/
                   df_plt['classes'].value_counts().dropna())
sns.barplot(x=agreement_level_maj.index, 
            y=agreement_level_maj.values,
            order=agreement_level_maj.sort_values(ascending=False).index,
            palette='Oranges', alpha = 1,
            ax=ax, label='Majority Agreement (>50%)')
sns.barplot(x=agreement_level_high.index, 
            y=agreement_level_high.values,
            order=agreement_level_maj.sort_values(ascending=False).index,
            palette='Blues_r', alpha = 0.75,
            ax=ax, label= 'High Agreement (>66%)')
plt.xticks(rotation=80)

plt.title('Class Distribution by Majority Agreement', fontsize=14)
plt.ylabel('Percent Agreement', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# We can get additional information about the above by looking at a box plot to see the median values and quartile ranges of agreement for each class distribution.

# %%
df_plt = df.melt(var_name='classes', value_name='percent')
plt.subplots(figsize=(16,8))
sns.boxplot(x='classes', y='percent', data=df_plt, 
            order=df.median().sort_values(ascending=False).index, fliersize=0)
plt.title('Class Distribution by Majority Agreement', fontsize=14)
plt.xlabel('Classes', fontsize=12)
plt.ylabel('Percent Agreement', fontsize=12)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# Important information that can be gleaned from this, from left to right:
# <ol>
#     <li>There is nothing "odd" about the majority of labelled galaxy images. (Class 6.2 compared to 6.1)</li>
#     <li>More than half of galaxy images include some kind of feature or disk, but a significant range is observed in the every quartile (Class 1.1)</li>
#     <li>Around 40% of galaxies could *not* be disks viewed edge-on, though significant range is oberved in every quartile. (Class 2.2 compared to 2.1)</li>
#     <li>Where galaxies are not disks viewed edge-on, most tend not have have a bar (Class 3.2 compared to 3.1)
# </ol>

# %%
plt.subplots(figsize=(12,6))
sns.barplot(x=df.columns, y=df.max(),
            order=df.max().sort_values(ascending=False).index,
            palette='mako')
plt.xticks(rotation=80)
plt.grid(axis='y', color='white')
plt.title('Maximum Agreement Per Class', fontsize=14)
plt.ylabel('Maximum Percent Agreement', fontsize=12)

plt.show()

# %% [markdown]
# Because some tasks in the data labelling process lead to others, we would expect to see a strong measure of correlation between specific classes.
# This should be observable in a correlation matrix.

# %%
plt.subplots(figsize=(12,12))
sns.heatmap(df.corr(), cmap='Greys_r')
plt.show()

# %% [markdown]
# Looking closely at the above, we find about what we would expect. The starting and ending tasks (classes 1 and 6) with a “yes” or “no” distinction are clearly negatively correlated. The other “yes” and “no” classes vary since they are dependent on other tasks. Other classes can be evaluated one-by-one to see that they make since. For instance, since the first answer on task one would send a crowd-sourced data labeller on to task 7, Class 1.1 correlates highly with classes 7.1 and 7.2. As could be seen in the description of the dataframe, class 7.3 was assigned rather uncommonly (with a mean value of 0.05), which explains the lesser degree of correlation there. Stepping through each class similarly, we can observe the patterns defined by the data-labelling task list.

# %% [markdown]
# To finish up the exploring this data, it would be interesting to see if galaxies that are classified with a high degree of agreement visually correspond with their Hubble classification.

# %%
e_filt = df['Class1.1'] > .9
s_filt = (df['Class4.1'] > 0.9) & (df['Class3.2'] > 0.9)
sb_filt = (df['Class4.1'] > 0.9) & (df['Class3.1'] > 0.9)

e_galaxy_fn = './' + str(df[e_filt].iloc[0].name) + '.jpg'
s_galaxy_fn = './' + str(df[s_filt].iloc[0].name) + '.jpg'
sb_galaxy_fn = './' + str(df[sb_filt].iloc[0].name) + '.jpg'

print('Elliptical class: {}, Spiral class {}, Spiral-bar class {}'.format(df[e_filt].iloc[0].name,
                                                                          df[s_filt].iloc[0].name,
                                                                          df[sb_filt].iloc[0].name))
# Out:
# Elliptical class: 464921, Spiral class 760198, Spiral-bar class 405615

# %%
e_img = plt.imread(e_galaxy_fn)
s_img = plt.imread(s_galaxy_fn)
sb_img = plt.imread(sb_galaxy_fn)
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(16, 6))
ax1.imshow(e_img)
ax2.imshow(s_img)
ax3.imshow(sb_img)
plt.show()

# %%
galaxy_types = {'elliptical': e_filt, 'spiral': s_filt, 'spiral-bar': sb_filt}
for key in galaxy_types:
    print('There are {} galaxies classified as {} with over 90% agreement.'. format(galaxy_types[key].sum(), key))
# Out:
# There are 1673 galaxies classified as elliptical with over 90% agreement.
# There are 234 galaxies classified as spiral with over 90% agreement.
# There are 77 galaxies classified as spiral-bar with over 90% agreement.
